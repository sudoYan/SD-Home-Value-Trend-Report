# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import time

df = pd.read_csv("sd_zhvi_2000_to_2025_nhbd.csv")
neighborhoods = df['RegionName'].dropna().unique()

geolocator = Nominatim(user_agent="your_email@example.com")  

def geocode_neighborhood(name):
    try:
        location = geolocator.geocode(f"{name}, San Diego, CA")
        if location:
            return name, location.latitude, location.longitude
        else:
            return name, None, None
    except (GeocoderTimedOut, GeocoderServiceError) as e:
        print(f"Error geocoding {name}: {e}")
        return name, None, None

results = []
for name in neighborhoods:
    results.append(geocode_neighborhood(name))
    time.sleep(2)

geo_df = pd.DataFrame(results, columns=["Neighborhood", "Latitude", "Longitude"])
geo_df.to_csv("geocoded_neighborhoods.csv", index=False)
# Out:
# Error geocoding La Jolla: Service timed out
# Error geocoding Clairemont Mesa East: Service timed out
# Error geocoding Bay Park: Service timed out
# Error geocoding Mountain View: Service timed out
# Error geocoding Encanto: Service timed out
# Error geocoding Oak Park: Service timed out
# Error geocoding Hillcrest: Service timed out
# Error geocoding Nestor: Service timed out
# Error geocoding Bay Ho: Service timed out
# Error geocoding Ocean Crest: Service timed out
# Error geocoding Miramar Ranch North: Service timed out
# Error geocoding East Village: Service timed out
# Error geocoding Valencia Park: Service timed out
# Error geocoding Mission Valley East: Service timed out
# Error geocoding Colina del Sol: Service timed out
# Error geocoding Clairemont Mesa West: Service timed out
# Error geocoding Midway District: Service timed out
# Error geocoding Bankers Hill: Service timed out
# ---------------------------------------------------------------------------
# ...
